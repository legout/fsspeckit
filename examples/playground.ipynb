# %%
from fsspeckit.datasets.pyarrow import PyarrowDatasetIO
from fsspeckit import filesystem

# %%
fs=filesystem("s3://test/ewn/mms2", profile="lodl", allow_invalid_certificates=True)
pdio=PyarrowDatasetIO(fs)

# %%
pdio.filesystem.ls("")
# Out:
# ---------------------------------------------------------------------------
# ProfileNotFound                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pdio.filesystem.ls("")
#
# File ~/coding/fsspeckit/src/fsspeckit/core/filesystem/__init__.py:98, in dirfs_ls_default_detail_false(self, path, detail, **kwargs)
#      95 def dirfs_ls_default_detail_false(
#      96     self, path: str, detail: bool = False, **kwargs: Any
#      97 ) -> Any:
# ---> 98     return _orig_dirfs_ls(self, path, detail=detail, **kwargs)
#
# File ~/coding/fsspeckit/.venv/lib/python3.13/site-packages/fsspec/implementations/dirfs.py:259, in DirFileSystem.ls(self, path, detail, **kwargs)
#     258 def ls(self, path, detail=True, **kwargs):
# --> 259     ret = self.fs.ls(self._join(path), detail=detail, **kwargs).copy()
#     260     if detail:
#     261         out = []
#
# ...
